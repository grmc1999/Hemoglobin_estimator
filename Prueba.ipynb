# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ls *.csv
# Out:
# db_sample_201901221525.csv

# %%
df = pd.read_csv("db_sample_201901221525.csv")

# %%
df.shape
# Out:
# (1232, 4)

# %%
df.head(5)
# Out:
#    Unnamed: 0         imagename      ane_cue  ane_glo
# 0          45  c1anemia-100.jpg  10.9-12.3-0     12.9
# 1          46  c1anemia-101.jpg  11.1-12.2-0     12.4
# 2          47  c1anemia-102.jpg  10.6-10.8-0     11.7
# 3          48  c1anemia-103.jpg  10.9-12.2-0     11.3
# 4          49  c1anemia-104.jpg  10.6-10.8-0     11.7

# %%
df.describe()
# Out:
#         Unnamed: 0      ane_glo
# count  1232.000000  1232.000000
# mean    615.500000    18.806201
# std     355.792074   232.143732
# min       0.000000     0.000000
# 25%     307.750000    11.200000
# 50%     615.500000    12.100000
# 75%     923.250000    12.900000
# max    1231.000000  8153.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'imagename', 'ane_cue', 'ane_glo'], dtype='object')

# %%
df.loc[df["imagename"]=="c1anemia-100.jpg", "ane_glo"].iloc[0]
# Out:
# 12.9

# %%
vdf = df[df["ane_glo"]>0][df["ane_glo"]<30]

# %%
sns.distplot(vdf["ane_glo"])
