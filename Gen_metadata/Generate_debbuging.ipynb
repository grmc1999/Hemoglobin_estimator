# %%
import sys
import pathlib
pth=str(pathlib.Path().absolute())
sys.path.append(('\\').join(pth.split('\\')[:-1])+"\\Utils")
from Utilities import *
import numpy as np
import skimage
from skimage import io
from skimage import color
import matplotlib.pyplot as plt
from skimage.segmentation import slic
from skimage.transform import rotate
from skimage import morphology
import networkx as nx
import json

# %%
f1=open(('\\').join(pth.split('\\')[:-2])+"\\Data_base\\validcrop.txt","r")
lines=f1.readlines()
linesn=np.array(lines)
linesn=np.delete(lines,np.where(linesn=="\n"))
linesn=linesn.reshape(-1,3)
#print(linesn[103:])
#linesn=linesn[103:]

linesnc=v_replace_err(linesn)
linesnc=np.vectorize(pyfunc=lambda x:np.array([x[0].split('\n')[0]]),signature="(n)->(m)")(linesnc.reshape(-1,1)).reshape(-1,3)
xywh=linesnc[:,:2]
imgnames=linesnc[:,2]
xywh=v_no_spaces(xywh)
xywh=np.vectorize(pyfunc=(lambda x:float(x)))(xywh.reshape(1,-1)[0])
xywh=xywh.reshape(-1,4).astype(int)+1

dir_origin=('\\').join(pth.split('\\')[:-2])+'\\Data_base\\Imagenes_originales\\'
dir_ROI=('\\').join(pth.split('\\')[:-2])+'\\Data_base\\Sem_Auto\\eye_'
dir_meta=('\\').join(pth.split('\\')[:-2])+'\\Data_base\\Metadata_V7G_sckit\\'

# %%
name=imgnames[0]
img = io.imread(dir_origin+name)
ROI = io.imread(dir_ROI+name)
mask=assemble_mask(xywh[np.where(imgnames==(name))][0],img,ROI)

for ang in np.arange(0,360,360/6):
    print(ang)
    SD,G,h,edges=get_graph_from_image(img,mask,desired_nodes=20,angle=ang)
    Sampled=sample_central(SD,G,num=5,maxdeg=3)
    NSD={}
    for ID in Sampled:
        NSD[ID]=SD[ID]
    print(NSD)
# Out:
# 0.0
# E:\Lab_repo\LIIARPI_1\Utils\Utilities.py:333: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data=np.array(list(node_features[node].items()))[:,1]
# {7: {'rgb_mean': array([0.6415783 , 0.57089795, 0.06596234]), 'rgb_std': array([0.02168265, 0.02115805, 0.00645066]), 'rgb_per': array([0.58823529, 0.51764706, 0.04700855]), 'rgb_mo': array([0.62745098, 0.55686275, 0.06382979]), 'lab_mean': array([ 7.22240746, 13.08502291, 69.14713999]), 'lab_std': array([0.91327791, 1.03258234, 1.98701528]), 'lab_per': array([ 5.51015778,  9.54194643, 64.21237934]), 'lab_mo': array([ 6.80704848, 12.32726384, 67.79214175]), 'hsv_mean': array([ 0.23813946,  0.74920843, 69.14713999]), 'hsv_std': array([0.01204853, 0.020399  , 1.98701528]), 'hsv_per': array([ 0.19815668,  0.70196078, 64.21237934]), 'hsv_mo': array([ 0.23036649,  0.7372549 , 67.79214175]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.77473191, 0.07589787, 0.        ]), 'lCh_per': array([12.71655636,  0.84196353,  7.        ]), 'lCh_mo': array([14.46250891,  1.0372328 ,  7.        ]), 'x_mean': 1572.0229007633588, 'x_std': 12.328497149581993, 'y_mean': 1945.7833235466824, 'y_std': 11.748715810153152, 'N': 1703}, 11: {'rgb_mean': array([0.64872824, 0.58231775, 0.07232186]), 'rgb_std': array([0.02593934, 0.02812109, 0.00688929]), 'rgb_per': array([0.59215686, 0.50980392, 0.05555556]), 'rgb_mo': array([0.63137255, 0.56470588, 0.06589147]), 'lab_mean': array([ 5.31863711, 11.7366275 , 69.35828706]), 'lab_std': array([1.04254149, 1.13950518, 2.38657312]), 'lab_per': array([ 2.86374127, 10.05202447, 64.01859433]), 'lab_mo': array([ 4.49803058, 11.25443352, 67.69886293]), 'hsv_mean': array([ 0.20848518,  0.73545881, 69.35828706]), 'hsv_std': array([0.01881703, 0.02436427, 2.38657312]), 'hsv_per': array([ 0.16915423,  0.67843137, 64.01859433]), 'hsv_mo': array([ 0.19444444,  0.71764706, 67.69886293]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([1.13680952, 0.0805865 , 0.        ]), 'lCh_per': array([10.97723278,  0.94414232, 11.        ]), 'lCh_mo': array([12.07097916,  1.06657003, 11.        ]), 'x_mean': 1610.848528356066, 'x_std': 9.749373292691017, 'y_mean': 1810.2096195262025, 'y_std': 12.18612509054592, 'N': 1393}, 5: {'rgb_mean': array([0.63769427, 0.5660908 , 0.06227701]), 'rgb_std': array([0.01542873, 0.0170336 , 0.00497132]), 'rgb_per': array([0.59607843, 0.52156863, 0.04814815]), 'rgb_mo': array([0.62745098, 0.55294118, 0.06122449]), 'lab_mean': array([ 8.39489624, 13.67348743, 69.06642355]), 'lab_std': array([0.70564565, 0.99588748, 1.4078515 ]), 'lab_per': array([ 6.77114215, 11.07177402, 65.15764182]), 'lab_mo': array([ 8.22141283, 12.47972756, 68.30990993]), 'hsv_mean': array([ 0.25271757,  0.75742866, 69.06642355]), 'hsv_std': array([0.01261748, 0.01402112, 1.4078515 ]), 'hsv_per': array([ 0.21674877,  0.71764706, 65.15764182]), 'hsv_mo': array([ 0.24226804,  0.74901961, 68.30990993]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.79283467, 0.05846259, 0.        ]), 'lCh_per': array([14.18173454,  0.85384719,  5.        ]), 'lCh_mo': array([15.42487298,  1.00592959,  5.        ]), 'x_mean': 1564.9158810732415, 'x_std': 12.928885710591846, 'y_mean': 2007.0949963741841, 'y_std': 9.079399798831469, 'N': 1379}, 15: {'rgb_mean': array([0.5612027 , 0.48098986, 0.07367177]), 'rgb_std': array([0.02039354, 0.02395171, 0.00553169]), 'rgb_per': array([0.50196078, 0.42745098, 0.05555556]), 'rgb_mo': array([0.54901961, 0.4627451 , 0.06884058]), 'lab_mean': array([ 6.48488039, 14.49641828, 61.23544046]), 'lab_std': array([0.85007527, 1.15823338, 1.89637692]), 'lab_per': array([ 4.40756962, 11.1494689 , 55.59587177]), 'lab_mo': array([ 6.11750091, 13.89832057, 59.94702536]), 'hsv_mean': array([ 0.27411554,  0.66228354, 61.23544046]), 'hsv_std': array([0.01957109, 0.01734503, 1.89637692]), 'hsv_per': array([ 0.20652174,  0.60784314, 55.59 ...
# 60.0
# {10: {'rgb_mean': array([0.65095789, 0.59306235, 0.06352277]), 'rgb_std': array([0.0180145 , 0.01749021, 0.00698821]), 'rgb_per': array([0.60533796, 0.54277901, 0.05      ]), 'rgb_mo': array([0.63995489, 0.58178351, 0.05698455]), 'lab_mean': array([ 6.36599561, 10.8650356 , 69.79492241]), 'lab_std': array([1.0474687 , 0.81087132, 1.68076655]), 'lab_per': array([ 4.39508853,  9.6189551 , 65.82722008]), 'lab_mo': array([ 5.72139616, 10.2235536 , 68.68005073]), 'hsv_mean': array([ 0.20410266,  0.74514504, 69.79492241]), 'hsv_std': array([0.01104557, 0.01923052, 1.68076655]), 'hsv_per': array([ 0.17886214,  0.7012892 , 65.82722008]), 'hsv_mo': array([ 0.1958502 ,  0.73036121, 68.68005073]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.77952341, 0.08385912, 0.        ]), 'lCh_per': array([11.15135473,  0.87776687, 10.        ]), 'lCh_mo': array([11.99371655,  0.9621657 , 10.        ]), 'x_mean': 1560.7617942768754, 'x_std': 11.455912080954382, 'y_mean': 1328.1701469450888, 'y_std': 10.089336742836387, 'N': 1293}, 8: {'rgb_mean': array([0.6507209 , 0.5849988 , 0.06676025]), 'rgb_std': array([0.01521862, 0.01786528, 0.00575973]), 'rgb_per': array([0.61550377, 0.5367819 , 0.05555556]), 'rgb_mo': array([0.63986787, 0.57231369, 0.0610121 ]), 'lab_mean': array([ 6.44478764, 12.04299562, 69.818411  ]), 'lab_std': array([0.78173153, 1.187554  , 1.37547261]), 'lab_per': array([ 4.11437456, 10.09268881, 66.39863638]), 'lab_mo': array([ 5.79773905, 11.26096265, 68.87437773]), 'hsv_mean': array([ 0.21879568,  0.74877876, 69.818411  ]), 'hsv_std': array([0.01597912, 0.01378471, 1.37547261]), 'hsv_per': array([ 0.17810024,  0.70451443, 66.39863638]), 'hsv_mo': array([ 0.20727362,  0.74005936, 68.87437773]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([1.07636414, 0.06772845, 0.        ]), 'lCh_per': array([11.10911955,  0.94262817,  8.        ]), 'lCh_mo': array([12.91657809,  1.01148942,  8.        ]), 'x_mean': 1529.5271587743732, 'x_std': 10.017739864018592, 'y_mean': 1312.8621169916435, 'y_std': 12.505839838201046, 'N': 1436}, 11: {'rgb_mean': array([0.6510269 , 0.58834635, 0.0675049 ]), 'rgb_std': array([0.02654006, 0.02897144, 0.0050133 ]), 'rgb_per': array([0.60314464, 0.52709993, 0.05555556]), 'rgb_mo': array([0.63482424, 0.57190374, 0.06481481]), 'lab_mean': array([ 5.96356464, 11.42016033, 69.71648745]), 'lab_std': array([0.76187435, 1.12080917, 2.44356401]), 'lab_per': array([ 3.96259581,  9.85901642, 65.37323469]), 'lab_mo': array([ 5.63595766, 10.32434901, 68.1948732 ]), 'hsv_mean': array([ 0.20838113,  0.74294122, 69.71648745]), 'hsv_std': array([0.01825457, 0.02465068, 2.44356401]), 'hsv_per': array([ 0.16536264,  0.68915685, 65.37323469]), 'hsv_mo': array([ 0.19459459,  0.72791136, 68.1948732 ]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([1.11056068, 0.05901362, 0.        ]), 'lCh_per': array([10.9460046 ,  0.94247064, 11.        ]), 'lCh_mo': array([11.79000211,  1.05902656, 11.        ]), 'x_mean': 1579.7785185185185, 'x_std': 11.343288994494499, 'y_mean': 1294.5407407407408, 'y_std': 9.922785572881097, 'N': 1350}, 9: {'rgb_mean': array([0.66730803, 0.60785716, 0.06370898]), 'rgb_std': array([0.01912289, 0.02174946, 0.00437025]), 'rgb_per': array([0.61815961, 0.54594577, 0.05555556]), 'rgb_mo': array([0.65559437, 0.5923611 , 0.06097561]), 'lab_mean': array([ 6.44442021, 11.08387896, 71.37140791]), 'lab_std': array([0.78821563, 1.06295457, 1.69293659]), 'lab_per': array([ 4.8054719 ,  9.95162406, 66.85921931]), 'lab_mo': array([ 5.66045506, 10.11649052, 70.3888641 ]), 'hsv_mean': array([ 0.20380422,  0.76330659, 71.37140791]), 'hsv_std': array([0.01758172, 0.01533669, 1.69293659]), 'hsv_per': array([ 0.17299875,  0.71592938, 66 ...
# 120.0
# {11: {'rgb_mean': array([0.61488942, 0.54995374, 0.06577566]), 'rgb_std': array([0.01436898, 0.01702521, 0.00694007]), 'rgb_per': array([0.5613004 , 0.49463374, 0.04824561]), 'rgb_mo': array([0.60474364, 0.53725792, 0.06097561]), 'lab_mean': array([ 6.66105637, 12.10620482, 66.4379747 ]), 'lab_std': array([0.79160047, 1.37429895, 1.33709631]), 'lab_per': array([ 4.12782397,  9.43231522, 61.44316312]), 'lab_mo': array([ 6.01655051, 11.33030383, 65.47145007]), 'hsv_mean': array([ 0.22959386,  0.7138056 , 66.4379747 ]), 'hsv_std': array([0.01618941, 0.01408825, 1.33709631]), 'hsv_per': array([ 0.1868919 ,  0.66718276, 61.44316312]), 'hsv_mo': array([ 0.22003771,  0.70345022, 65.47145007]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([1.11331149, 0.08055433, 0.        ]), 'lCh_per': array([11.60633391,  0.85633648, 11.        ]), 'lCh_mo': array([12.98174848,  1.00824966, 11.        ]), 'x_mean': 2089.4743918053778, 'x_std': 11.838690548378471, 'y_mean': 1064.8501920614597, 'y_std': 11.813340864052078, 'N': 1562}, 13: {'rgb_mean': array([0.61839899, 0.550442  , 0.07528225]), 'rgb_std': array([0.02430893, 0.02505106, 0.00510702]), 'rgb_per': array([0.54152832, 0.47878322, 0.06138276]), 'rgb_mo': array([0.60245609, 0.53349547, 0.07317073]), 'lab_mean': array([ 4.92407911, 11.9042643 , 66.36766518]), 'lab_std': array([0.82330928, 0.87029015, 2.23953295]), 'lab_per': array([ 3.29115704, 10.21995119, 59.1565844 ]), 'lab_mo': array([ 4.3942371 , 11.45402331, 64.95373217]), 'hsv_mean': array([ 0.21504907,  0.70100935, 66.36766518]), 'hsv_std': array([0.01643841, 0.02174403, 2.23953295]), 'hsv_per': array([ 0.1779588,  0.6317244, 59.1565844]), 'hsv_mo': array([ 0.20373836,  0.6882212 , 64.95373217]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.9090542 , 0.05984301, 0.        ]), 'lCh_per': array([11.06092866,  1.01203938, 13.        ]), 'lCh_mo': array([12.20059263,  1.15096208, 13.        ]), 'x_mean': 2133.4975165562914, 'x_std': 13.23244784428462, 'y_mean': 1089.9056291390727, 'y_std': 9.309400367381913, 'N': 1208}, 10: {'rgb_mean': array([0.65560024, 0.59435977, 0.06518006]), 'rgb_std': array([0.02480712, 0.02963375, 0.0055013 ]), 'rgb_per': array([0.60262894, 0.51878907, 0.05555556]), 'rgb_mo': array([0.63608353, 0.57266964, 0.06097561]), 'lab_mean': array([ 6.3187332 , 11.33086514, 70.23253858]), 'lab_std': array([0.81546392, 1.22811584, 2.28222163]), 'lab_per': array([ 4.80029344,  9.88018316, 65.16860229]), 'lab_mo': array([ 5.66662817, 10.17688486, 68.36558006]), 'hsv_mean': array([ 0.20864001,  0.75069998, 70.23253858]), 'hsv_std': array([0.01990584, 0.02228351, 2.28222163]), 'hsv_per': array([ 0.16751666,  0.70066815, 65.16860229]), 'hsv_mo': array([ 0.19066386,  0.73263446, 68.36558006]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([1.19137041, 0.06451131, 0.        ]), 'lCh_per': array([11.30509587,  0.9424429 , 10.        ]), 'lCh_mo': array([11.72676932,  1.01073947, 10.        ]), 'x_mean': 2057.027537796976, 'x_std': 11.409461317015266, 'y_mean': 974.8525917926565, 'y_std': 14.32017331225352, 'N': 1852}, 8: {'rgb_mean': array([0.65352349, 0.58676467, 0.06532398]), 'rgb_std': array([0.01610626, 0.0187571 , 0.00626168]), 'rgb_per': array([0.61253784, 0.54312857, 0.05      ]), 'rgb_mo': array([0.64122351, 0.57230949, 0.06097561]), 'lab_mean': array([ 6.87504283, 12.3466615 , 70.19105135]), 'lab_std': array([0.68489703, 1.2422759 , 1.47530201]), 'lab_per': array([ 4.94585573, 10.0543373 , 66.56060026]), 'lab_mo': array([ 6.59017803, 11.21482849, 69.05313535]), 'hsv_mean': array([ 0.22446094,  0.75647357, 70.19105135]), 'hsv_std': array([0.01414101, 0.01463366, 1.47530201]), 'hsv_per': array([ 0.18108943,  0.72156863, 66.56060 ...
# 180.0
# {9: {'rgb_mean': array([0.55952026, 0.4795931 , 0.07189376]), 'rgb_std': array([0.01429368, 0.01969153, 0.00521868]), 'rgb_per': array([0.51764706, 0.42745098, 0.05555556]), 'rgb_mo': array([0.54901961, 0.46666667, 0.06884058]), 'lab_mean': array([ 6.8826142 , 14.60663633, 61.16827005]), 'lab_std': array([0.47756305, 1.1456316 , 1.42067442]), 'lab_per': array([ 6.12254664, 11.1494689 , 56.95517124]), 'lab_mo': array([ 6.28143434, 13.87888937, 60.16301337]), 'hsv_mean': array([ 0.27840337,  0.66438235, 61.16827005]), 'hsv_std': array([0.01485029, 0.0149105 , 1.42067442]), 'hsv_per': array([ 0.22580645,  0.61960784, 56.95517124]), 'hsv_mo': array([ 0.26900585,  0.65490196, 60.16301337]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.83077755, 0.05827159, 0.        ]), 'lCh_per': array([13.78092398,  0.94029575,  9.        ]), 'lCh_mo': array([15.61804297,  1.09412282,  9.        ]), 'x_mean': 2540.0644666155026, 'x_std': 9.17563696649051, 'y_mean': 1455.071373752878, 'y_std': 12.306471546903783, 'N': 1303}, 7: {'rgb_mean': array([0.64759998, 0.58917933, 0.06413114]), 'rgb_std': array([0.02434751, 0.02331801, 0.00650963]), 'rgb_per': array([0.58039216, 0.51372549, 0.05      ]), 'rgb_mo': array([0.63529412, 0.57647059, 0.06097561]), 'lab_mean': array([ 6.29886904, 10.92540545, 69.45729948]), 'lab_std': array([1.02202172, 0.82391225, 2.23620906]), 'lab_per': array([ 3.85066599,  9.61701868, 63.19241793]), 'lab_mo': array([ 5.72096618, 10.23177437, 68.1458444 ]), 'hsv_mean': array([ 0.20519936,  0.74119316, 69.45729948]), 'hsv_std': array([0.01337628, 0.02350774, 2.23620906]), 'hsv_per': array([ 0.16      ,  0.68235294, 63.19241793]), 'hsv_mo': array([ 0.19459459,  0.7254902 , 68.1458444 ]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.85284755, 0.07833226, 0.        ]), 'lCh_per': array([10.92744333,  0.87767434,  7.        ]), 'lCh_mo': array([11.75202788,  1.00838937,  7.        ]), 'x_mean': 2535.7033434650457, 'x_std': 12.135286827662153, 'y_mean': 1233.4960486322188, 'y_std': 11.92176177582744, 'N': 1645}, 2: {'rgb_mean': array([0.52348356, 0.43705402, 0.07417934]), 'rgb_std': array([0.02297048, 0.02066338, 0.00466627]), 'rgb_per': array([0.44705882, 0.36470588, 0.06603774]), 'rgb_mo': array([0.50980392, 0.42352941, 0.07142857]), 'lab_mean': array([ 7.127829  , 15.82325725, 57.69766037]), 'lab_std': array([1.07948226, 0.42825281, 2.06941519]), 'lab_per': array([ 5.4158967 , 14.10176915, 50.61337266]), 'lab_mo': array([ 6.29680941, 15.77641361, 56.42616899]), 'hsv_mean': array([ 0.30827307,  0.63151666, 57.69766037]), 'hsv_std': array([0.01595772, 0.01703993, 2.06941519]), 'hsv_per': array([ 0.27374302,  0.57254902, 50.61337266]), 'hsv_mo': array([ 0.2969697 ,  0.61960784, 56.42616899]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.63033913, 0.05528565, 0.        ]), 'lCh_per': array([15.89350795,  1.0469227 ,  2.        ]), 'lCh_mo': array([17.07911268,  1.11763376,  2.        ]), 'x_mean': 2526.9064587973276, 'x_std': 16.17933126138637, 'y_mean': 1489.5902004454342, 'y_std': 9.88340681391563, 'N': 1796}, 5: {'rgb_mean': array([0.6233433 , 0.55479894, 0.07633942]), 'rgb_std': array([0.02816462, 0.02881938, 0.00559557]), 'rgb_per': array([0.54117647, 0.47843137, 0.06097561]), 'rgb_mo': array([0.60392157, 0.5372549 , 0.07352941]), 'lab_mean': array([ 4.75177792, 11.91399937, 66.80145451]), 'lab_std': array([0.873334 , 0.9944345, 2.589035 ]), 'lab_per': array([ 2.8036727 , 10.16499107, 59.12220324]), 'lab_mo': array([ 4.18210845, 11.41709361, 65.0774296 ]), 'hsv_mean': array([ 0.2128864 ,  0.70453307, 66.80145451]), 'hsv_std': array([0.0184569 , 0.02486157, 2.589035  ]), 'hsv_per': array([ 0.17098446,  0.63137255, 59.12220324]) ...
# 240.0
# {9: {'rgb_mean': array([0.64383852, 0.57949838, 0.07201394]), 'rgb_std': array([0.02542888, 0.02580454, 0.00520058]), 'rgb_per': array([0.57203545, 0.51082537, 0.05570366]), 'rgb_mo': array([0.62722562, 0.56196773, 0.06837607]), 'lab_mean': array([ 5.21506014, 11.40591548, 68.86054716]), 'lab_std': array([0.90010122, 0.96680536, 2.35182424]), 'lab_per': array([ 3.1351815 , 10.08754648, 61.77368821]), 'lab_mo': array([ 4.47026042, 10.36111425, 67.42869349]), 'hsv_mean': array([ 0.20476494,  0.72858048, 68.86054716]), 'hsv_std': array([0.01701628, 0.02454478, 2.35182424]), 'hsv_per': array([ 0.16834544,  0.64654526, 61.77368821]), 'hsv_mo': array([ 0.19149389,  0.71517331, 67.42869349]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([1.05827192, 0.06206476, 0.        ]), 'lCh_per': array([10.96509051,  0.94599021,  9.        ]), 'lCh_mo': array([11.65997676,  1.0993116 ,  9.        ]), 'x_mean': 2518.830342577488, 'x_std': 11.594167658781403, 'y_mean': 1844.489396411093, 'y_std': 9.423442799055293, 'N': 1226}, 11: {'rgb_mean': array([0.6327151 , 0.57537547, 0.06263544]), 'rgb_std': array([0.0218647 , 0.0212605 , 0.00631185]), 'rgb_per': array([0.57662814, 0.51697169, 0.04529294]), 'rgb_mo': array([0.61675856, 0.56078431, 0.05656507]), 'lab_mean': array([ 6.58270912, 10.90952164, 68.10150262]), 'lab_std': array([1.11001902, 0.74449227, 1.90235054]), 'lab_per': array([ 4.28837452,  9.6189551 , 63.08938458]), 'lab_mo': array([ 5.72839504, 10.23543282, 66.70941848]), 'hsv_mean': array([ 0.21021798,  0.72834795, 68.10150262]), 'hsv_std': array([0.01585847, 0.01595544, 1.90235054]), 'hsv_per': array([ 0.16707919,  0.68559914, 63.08938458]), 'hsv_mo': array([ 0.19565989,  0.71764448, 66.70941848]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.90601356, 0.0767186 , 0.        ]), 'lCh_per': array([10.9460046,  0.8211109, 11.       ]), 'lCh_mo': array([11.76638913,  0.9566162 , 11.        ]), 'x_mean': 2570.8382949932343, 'x_std': 12.066918524132557, 'y_mean': 1793.2293640054127, 'y_std': 10.590650177337151, 'N': 1478}, 7: {'rgb_mean': array([0.61282925, 0.55005952, 0.06658708]), 'rgb_std': array([0.01588852, 0.01799251, 0.00697878]), 'rgb_per': array([0.54855315, 0.48451417, 0.04824561]), 'rgb_mo': array([0.6032284 , 0.53808918, 0.06097561]), 'lab_mean': array([ 6.30449009, 11.66120566, 66.14697794]), 'lab_std': array([1.02344964, 0.89552288, 1.47912596]), 'lab_per': array([ 4.12935213,  9.41138122, 59.83470629]), 'lab_mo': array([ 5.64062403, 11.29780909, 65.19922201]), 'hsv_mean': array([ 0.22237487,  0.70726201, 66.14697794]), 'hsv_std': array([0.01332961, 0.01579506, 1.47912596]), 'hsv_per': array([ 0.18631367,  0.63874923, 59.83470629]), 'hsv_mo': array([ 0.21430926,  0.69727547, 65.19922201]), 'LCh_mean': array([0., 0., 0.]), 'LCh_std': array([0., 0., 0.]), 'LCh_per': array([0., 0., 0.]), 'LCh_mo': array([0., 0., 0.]), 'lCh_std': array([0.79931435, 0.08291905, 0.        ]), 'lCh_per': array([11.59762292,  0.85636217,  7.        ]), 'lCh_mo': array([12.77940376,  1.00836784,  7.        ]), 'x_mean': 2486.1472303206997, 'x_std': 10.760995443783138, 'y_mean': 1824.3061224489795, 'y_std': 10.624708144557097, 'N': 1372}, 8: {'rgb_mean': array([0.61237075, 0.54086919, 0.06952429]), 'rgb_std': array([0.01926023, 0.01978806, 0.0083218 ]), 'rgb_per': array([0.54989486, 0.47663986, 0.05      ]), 'rgb_mo': array([0.60076441, 0.53068691, 0.06439394]), 'lab_mean': array([ 6.46234498, 13.01125311, 66.16813433]), 'lab_std': array([1.01845367, 1.33543125, 1.77812741]), 'lab_per': array([ 3.26760404, 10.16696447, 60.33602897]), 'lab_mo': array([ 5.9266458 , 12.45436709, 65.19292139]), 'hsv_mean': array([ 0.24018028,  0.71171388, 66.16813433]), 'hsv_std': array([0.0145583 , 0.01794413, 1.77812741]), 'hsv_per': array([ 0.20344847,  0.65393834, 60.33602 ...
# 300.0

# %%
img=rotate(img,0)
mask=rotate(mask,0)

# %%
mask=assemble_mask(xywh[np.where(imgnames==(name))][0],img,ROI)

# %%
mask=rotate(mask,180)
np.max(mask)
# Out:
# 1.1897645893482875e-07
